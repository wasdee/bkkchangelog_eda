# %%
import pandas as pd

df = pd.read_json('backup.ndjson', lines=True)

# %%
df
# Out:
#                type            org  \
# 0                    กรุงเทพมหานคร
# 1       ท่อระบายน้ำ  กรุงเทพมหานคร
# 2                    กรุงเทพมหานคร
# 3               ถนน  กรุงเทพมหานคร
# 4           ทางเท้า  กรุงเทพมหานคร
# ...             ...            ...
# 241415          ถนน  กรุงเทพมหานคร
# 241416       ต้นไม้  กรุงเทพมหานคร
# 241417  ถนน,ทางเท้า  กรุงเทพมหานคร
# 241418               กรุงเทพมหานคร
# 241419          ถนน  กรุงเทพมหานคร
#
#                                               description    ticket_id  \
# 0       พบเห็นคนเช็ดกระจกนำจักรยานโครงการปันปั่น เลขจั...  2023-6T66E8
# 1       พื้นชำระตรงจุดใกล้กับฝาท่อ ตรงบริเวณเกาะกลางถน...  2023-3BFK7U
# 2                                 รถจอดทิ้ง ซององครักษ์12  2023-9WD749
# 3       ปัญหา : มีการก่อสร้าง อาคารในเวลากลางคืน ส่งเส...       HHUWM6
# 4                                            ทางเท้าชำรุด  2023-EBPEF9
# ...                                                   ...          ...
# ...

# %%
df.groupby('ticket_id').count().sort_values('type', ascending=False).head(10)
# Out:
#              type  org  description  coords  photo_url  after_photo  address  \
# ticket_id
# 2023-K299PL     9    9            9       9          9            9        9
# 2023-DAPM3E     7    7            7       7          7            7        7
# 2023-GEUWAK     7    7            7       7          7            7        7
# 2023-ABZPGM     7    7            7       7          7            7        7
# 2023-EADA33     7    7            7       7          7            7        7
# 43WHPW          6    6            6       6          6            6        6
# 2023-7XB7HU     6    6            6       6          6            6        6
# 2023-KRQFNT     6    6            6       6          6            6        6
# MY9EG3          6    6            6       6          6            6        6
# HPNMEA          6    6            6       6          6            6        6
#
#              timestamp  problem_type_abdul  star  count_reopen  note  state  \
# ticket_id
# ...

# %%
import seaborn as sns

# plot histogram of
